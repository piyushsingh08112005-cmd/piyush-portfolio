# %% [markdown]
# # Pandas Basics
#
# **Language:** Python
#
# **Level:** expert

# %%
import pandas as pd

df = pd.DataFrame({'Name': ['A', 'B'], 'Marks': [85, 92]})
print(df)
print('Average:', df['Marks'].mean())
